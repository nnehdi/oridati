# %% [markdown]
# # Expriment

# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')

def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message["content"]

# %%
description = "A platform similar to Resident Advisor that provides information about upcoming music events, festivals, and concerts. The platform would allow users to search for events by location, genre, and date, and would provide detailed information about each event, including the lineup, venue, and ticket prices. Users could also create profiles to track their favorite artists and receive personalized recommendations for events based on their music preferences. The platform could generate revenue through ticket sales and partnerships with event organizers and sponsors. "
messages =  [  
{'role':'system', 'content':f"""
 You are OrigamiAnalyzer, a chabot designed to gather data model specification from the client.  \
 You and client work together to find out the following, You don't need to ask for this informations in sequence:\
 - Different type of  users or persona
 - Entitietis
 - Entitietis attributes
 - The relationship between those Entities
 - The relationship and interaction of users with Entities.

 Then You wil be having a conversation with user to help her , \
"""},
{'role':'assistant','content':'Hi I am OrigamiAnalyzer! Please provide me the initiale project description.'},
{'role':'user', 'content':description},
{'role':'assistant', 'content':'Great! To get started, lets identify the different types of users or personas that will be using this platform. Who do you think will be the primary users of this platform?'},
{'role':'user', 'content':'Party goers'},
{'role':'assistant', 'content':'Okay, so we can identify "Party goers" as one of the primary user personas. Can you think of any other types of users who might use this platform? For example, event organizers or promoters, or perhaps even artists or performers?'},
{'role':'user', 'content':'Yeah, promoters, Artists or DJs and Veneue owner'},
{'role':'system', 'content':'please output the users, entities in json format'},
]
response = get_completion_from_messages(messages, temperature=0)
print(response)
# Out:
# Sure, here's an example of what the JSON format might look like based on the information you've provided:
#
# ```
# {
#   "users": [
#     {
#       "name": "Party goers"
#     },
#     {
#       "name": "Promoters"
#     },
#     {
#       "name": "Artists or DJs"
#     },
#     {
#       "name": "Venue owners"
#     }
#   ],
#   "entities": [
#     {
#       "name": "Events",
#       "attributes": [
#         {
#           "name": "Location",
#           "type": "string"
#         },
#         {
#           "name": "Genre",
#           "type": "string"
#         },
#         {
#           "name": "Date",
#           "type": "date"
#         },
#         {
#           "name": "Lineup",
#           "type": "string"
#         },
#         {
#           "name": "Venue",
#           "type": "string"
#         },
#         {
#           "name": "Ticket prices",
#           "type": "float"
#         }
#       ]
#     },
#     {
#       "name": "Users",
#       "attributes": [
#         {
# ...
